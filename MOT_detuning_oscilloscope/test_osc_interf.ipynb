# %%
from interface_app import Interface_app as iapp

# %%
osc = iapp.Osc_RS()

# %% [markdown]
# Set channel 2 on and the other channels off

# %%
osc.Set_Channel(2)

# %% [markdown]
# Set verticale range to 0.5 V

# %%
osc.Set_vertical_range(0.5)
# range for mot charge = 0.5
# rnage for resonance = 1.0

# %% [markdown]
# Set time range to 5 seconds

# %%
osc.Set_horizontal_range(5)

# %% [markdown]
# Get data present on the oscilloscope

# %%
x_data, y_data = osc.Get_Data()
# Out:
# x_min = -5.9998018, x_max = 5.9997101, record_length = 130920.0

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(x_data, y_data)
